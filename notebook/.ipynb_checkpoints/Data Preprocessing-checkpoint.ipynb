# %%
import pandas as pd

# %%
df_1 = pd.read_csv('../data/kaggle_resume_dataset.csv')

# %%
df_2 = pd.read_csv('../data/website_resumes.csv')
df_2 = df_2.drop_duplicates()

# %%
df_3 = pd.read_csv('../data/2480resumes.csv')

# %%
df_3 = df_3[['category', 'resume']]

# %%
df_1.rename(columns = {'Category':'category','Resume':'resume'}, inplace=True)

# %%
full_df = pd.concat([df_1,df_2, df_3])
full_df.category = full_df.category.str.lower()

# %%
df_1[df_1.resume.str.contains("COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS")]
# Out:
#     category                                             resume
# 897  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 904  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 911  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 918  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 925  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 932  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 939  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 946  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 953  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 960  Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...

# %%
df_1.drop_duplicates()
# Out:
#          category                                             resume
# 0    Data Science  Skills * Programming Languages: Python (pandas...
# 1    Data Science  Education Details \r\nMay 2013 to May 2017 B.E...
# 2    Data Science  Areas of Interest Deep Learning, Control Syste...
# 3    Data Science  Skills â¢ R â¢ Python â¢ SAP HANA â¢ Table...
# 4    Data Science  Education Details \r\n MCA   YMCAUST,  Faridab...
# ..            ...                                                ...
# 894       Testing  Computer Skills: â¢ Proficient in MS office (...
# 895       Testing  â Willingness to accept the challenges. â ...
# 896       Testing  PERSONAL SKILLS â¢ Quick learner, â¢ Eagerne...
# 897       Testing  COMPUTER SKILLS & SOFTWARE KNOWLEDGE MS-Power ...
# 898       Testing  Skill Set OS Windows XP/7/8/8.1/10 Database MY...
#
# [166 rows x 2 columns]

# %%
df_3.drop_duplicates()
# Out:
#          category                                             resume
# 0     AGRICULTURE  ADULT EDUCATION INSTRUCTOR\r\nSummary\r\nSeaso...
# 2     AGRICULTURE  FINANCIAL SALES CONSULTANT\r\nProfessional Sum...
# 3     AGRICULTURE  EXTENSION METHODOLOGIST\r\nProfile\r\nSelf-mot...
# 4     AGRICULTURE  RESEARCH SCIENTIST\r\nSummary\r\n\r\nHighly mo...
# 5     AGRICULTURE  FRONT DESK CLERK (FEE BASIS, JOHN D DINGELL VA...
# ...           ...                                                ...
# 2491   AUTOMOBILE  GENERAL LIABILITY CLAIM REPRESENTATIVE\r\nSumm...
# 2492   AUTOMOBILE  AUTOMOBILE TRANSPORTER\r\nProfessional Summary...
# 2493   AUTOMOBILE  Highlights\r\n\r\nProg. Languages: C (5+ yrs),...
# 2494   AUTOMOBILE  CUSTOMER RELATIONS SPECIALIST\r\nSummary\r\n\r...
# 2495   AUTOMOBILE  SENIOR SPECIAL INVESTIGATOR\r\nSummary\r\n\r\n...
#
# [2482 rows x 2 columns]

# %%
full_df.to_csv('../data/full_dataset.csv')

# %%
print(df_1['Resume'][10])
# Out:
# Skills * Programming Languages: Python (pandas, numpy, scipy, scikit-learn, matplotlib), Sql, Java, JavaScript/JQuery. * Machine learning: Regression, SVM, NaÃ¯ve Bayes, KNN, Random Forest, Decision Trees, Boosting techniques, Cluster Analysis, Word Embedding, Sentiment Analysis, Natural Language processing, Dimensionality reduction, Topic Modelling (LDA, NMF), PCA & Neural Nets. * Database Visualizations: Mysql, SqlServer, Cassandra, Hbase, ElasticSearch D3.js, DC.js, Plotly, kibana, matplotlib, ggplot, Tableau. * Others: Regular Expression, HTML, CSS, Angular 6, Logstash, Kafka, Python Flask, Git, Docker, computer vision - Open CV and understanding of Deep learning.Education Details
#
# Data Science Assurance Associate
#
# Data Science Assurance Associate - Ernst & Young LLP
# Skill Details
# JAVASCRIPT- Exprience - 24 months
# jQuery- Exprience - 24 months
# Python- Exprience - 24 monthsCompany Details
# company - Ernst & Young LLP
# ...
